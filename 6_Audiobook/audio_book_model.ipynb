# %%
import numpy as np
import tensorflow as tf

# %%
npz = np.load('audiobooks_data_train.npz')
train_inputs = npz['inputs'].astype(float)
train_targets = npz['targets'].astype(int)

npz = np.load('audiobooks_data_validation.npz')
validation_inputs = npz['inputs'].astype(float)
validation_targets = npz['targets'].astype(int)

npz = np.load('audiobooks_data_test.npz')
test_inputs = npz['inputs'].astype(float)
test_targets = npz['targets'].astype(int)

# %%
input_size = 10
output_size = 2
hidden_layer_size = 100

model = tf.keras.Sequential([
    tf.keras.layers.Dense(hidden_layer_size,activation='relu'),
    tf.keras.layers.Dense(hidden_layer_size,activation='relu'),
    tf.keras.layers.Dense(hidden_layer_size,activation='sigmoid'),
    tf.keras.layers.Dense(output_size,activation='softmax'),
])

model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

batch_size = 100
epochs = 100
early_stopping = tf.keras.callbacks.EarlyStopping(patience=2)

model.fit(train_inputs,train_targets,batch_size=batch_size,epochs=epochs, callbacks=[early_stopping],validation_data=(validation_inputs,validation_targets),verbose=2)
test_loss,test_accuracy = model.evaluate(test_inputs,test_targets)
# Out:
# Epoch 1/100
# 36/36 - 3s - 78ms/step - accuracy: 0.6675 - loss: 0.5810 - val_accuracy: 0.7651 - val_loss: 0.4579
# Epoch 2/100
# 36/36 - 0s - 6ms/step - accuracy: 0.7745 - loss: 0.4157 - val_accuracy: 0.8098 - val_loss: 0.3743
# Epoch 3/100
# 36/36 - 0s - 6ms/step - accuracy: 0.7890 - loss: 0.3786 - val_accuracy: 0.7651 - val_loss: 0.3766
# Epoch 4/100
# 36/36 - 0s - 6ms/step - accuracy: 0.8008 - loss: 0.3623 - val_accuracy: 0.8009 - val_loss: 0.3595
# Epoch 5/100
# 36/36 - 0s - 6ms/step - accuracy: 0.8033 - loss: 0.3552 - val_accuracy: 0.8300 - val_loss: 0.3394
# Epoch 6/100
# 36/36 - 0s - 6ms/step - accuracy: 0.8167 - loss: 0.3435 - val_accuracy: 0.8054 - val_loss: 0.3338
# Epoch 7/100
# 36/36 - 0s - 6ms/step - accuracy: 0.8050 - loss: 0.3444 - val_accuracy: 0.8210 - val_loss: 0.3276
# Epoch 8/100
# 36/36 - 0s - 8ms/step - accuracy: 0.8173 - loss: 0.3385 - val_accuracy: 0.8076 - val_loss: 0.3324
# Epoch 9/100
# 36/36 - 0s - 6ms/step - accuracy: 0.8153 - loss: 0.3347 - val_accuracy: 0.8367 - val_loss: 0.3237
# Epoch 10/100
# 36/36 - 0s - 6ms/step - accuracy: 0.8248 - loss: 0.3303 - val_accuracy: 0.8277 - val_loss: 0.3187
# Epoch 11/100
# 36/36 - 0s - 6ms/step - accuracy: 0.8312 - loss: 0.3261 - val_accuracy: 0.8255 - val_loss: 0.3247
# Epoch 12/100
# 36/36 - 0s - 6ms/step - accuracy: 0.8103 - loss: 0.3339 - val_accuracy: 0.8166 - val_loss: 0.3185
# Epoch 13/100
# 36/36 - 0s - 6ms/step - accuracy: 0.8248 - loss: 0.3242 - val_accuracy: 0.8345 - val_loss: 0.3165
# Epoch 14/100
# 36/36 - 0s - 6ms/step - accuracy: 0.8237 - loss: 0.3229 - val_accuracy: 0.8098 - val_loss: 0.3358
# Epoch 15/100
# 36/36 - 0s - 6ms/step - accuracy: 0.8256 - loss: 0.3198 - val_accuracy: 0.8188 - val_loss: 0.3236
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8393 - loss: 0.3299

# %%
test_loss, test_accuracy = model.evaluate(test_inputs, test_targets)

print(test_loss)
print(test_accuracy)
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8393 - loss: 0.3299
# 0.32993218302726746
# 0.8392857313156128
